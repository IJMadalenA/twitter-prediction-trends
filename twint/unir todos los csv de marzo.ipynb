# %%
import numpy as np
import pandas as pd
import os

# %%
"""
Une todos los csv del mes de marzo (sirve para cada mes)
crea un csv con todos los csv
"""

# %%
os.chdir("C:/Users/Daniel/Desktop/proyecto/notebooks/csv mes de marzo")

# %%
df = pd.DataFrame()

# %%
os.listdir()
# Out:
# ['#11M2020_2020-03-11.csv',
#  '#11Marzo_2020-03-11.csv',
#  '#155coronavirus_2020-03-15.csv',
#  '#1MCallMeMaybe_2020-03-25.csv',
#  '#1MDontStartNow_2020-03-26.csv',
#  '#1millonGentleman_2020-03-17.csv',
#  '#2012Live_2020-03-21.csv',
#  '#24hLiveSBR_2020-03-16.csv',
#  '#28Mar_2020-03-28.csv',
#  '#2añoslibres_2020-03-02.csv',
#  '#2DiasMeSabeASal_2020-03-25.csv',
#  '#2YearsIntoHopeWorld_2020-03-01.csv',
#  '#3AbrilLDDTS_2020-03-09.csv',
#  '#3añosgrefg_2020-03-19.csv',
#  '#5SOS_2020-03-26.csv',
#  '#8Marzo_2020-03-08.csv',
#  '#8Myonovoy_2020-03-08.csv',
#  '#A3Boom_2020-03-13.csv',
#  '#abascal_2020-03-25.csv',
#  '#AbogaciaMaltratada_2020-03-29.csv',
#  '#AbogacíaAbandonada_2020-03-26.csv',
#  '#AbrazosParaAnaGuerra_2020-03-25.csv',
#  '#ACNintenderosIG_2020-03-13.csv',
#  '#AcusticoRickyEnCasa_2020-03-17.csv',
#  '#AdivinaElVideojuego2_2020-03-26.csv',
#  '#AfterHours_2020-03-20.csv',
#  '#AgoneyHolika2020_2020-03-05.csv',
#  '#agujaflamenca1_2020-03-06.csv',
# ...

# %%
# %%time
for csv in os.listdir():
    df1 = pd.read_csv(csv)
    df1["trend"] = [csv.split("_")[0] for i in range(df1.shape[0])]
    df = pd.concat([df, df1])
# Out:
# <string>:2: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
# Wall time: 5h 1min 55s

# %%
#df1 = pd.read_csv(os.listdir()[0])

# %%
#df1["trend"] = [os.listdir()[0].split("_")[0] for i in range(df1.shape[0])]

# %%
#df = pd.concat([df, df1])

# %%
#df = pd.concat([df, pd.read_csv(os.listdir()[1])])

# %%
df
# Out:
#                       id      conversation_id  \
# 0    1237890662063718405  1237890662063718405
# 1    1237868868820819969  1237868868820819969
# 2    1237866992033398785  1237861365672374273
# 3    1237866485571153925  1237788066921807872
# 4    1237863957735460866  1237863957735460866
# ..                   ...                  ...
# 166  1242714315213373440  1242714315213373440
# 167  1242711413044514823  1242583160250130432
# 168  1242681025613963266  1242565771420749825
# 169  1242629976467234817  1242629976467234817
# 170  1242619535909359618  1242591867314847744
#
#                                     created_at        date      time  \
# 0    2020-03-12 00:58:27 Hora estándar romance  2020-03-12  00:58:27
# 1    2020-03-11 23:31:51 Hora estándar romance  2020-03-11  23:31:51
# 2    2020-03-11 23:24:24 Hora estándar romance  2020-03-11  23:24:24
# 3    2020-03-11 23:22:23 Hora estándar romance  2020-03-11  23:22:23
# ...

# %%
df.shape
# Out:
# (4618317, 37)

# %%
df.to_csv("trends_marzo.csv", sep = ";", index = False)
