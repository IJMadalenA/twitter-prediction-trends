# %%
import numpy as np
import pandas as pd

# %%
df_24_t = pd.read_csv("C:/Users/Daniel/Desktop/csv/def/tweets_24_tendencias_variables_7h.csv", sep = ";")
df_24_nt = pd.read_csv("C:/Users/Daniel/Desktop/csv/def/tweets_24_notendencias_variables_7h.csv", sep = ";")
df_25_t = pd.read_csv("C:/Users/Daniel/Desktop/csv/def/tweets_25_tendencias_variables_7h.csv", sep = ";")
df_25_nt = pd.read_csv("C:/Users/Daniel/Desktop/csv/def/tweets_25_notendencias_variables_7h.csv", sep = ";")

# %%
dfs = [df_24_t]
df_24 = pd.DataFrame()
for dataf in dfs:
    df_aux = dataf
    df_aux["target"] = [1 for i in range(df_aux.shape[0])]
    df_24 = pd.concat([df_24, df_aux])
    
dfs = [df_24_nt]
for dataf in dfs:
    df_aux = dataf
    df_aux["target"] = [0 for i in range(df_aux.shape[0])]
    df_24 = pd.concat([df_24, df_aux])

# %%
df = pd.concat([df_t, df_nt])

# %%
df.to_csv("tweets_24_25_variables_target.csv", sep = ";", index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2c8c1fe819d6> in <module>
# ----> 1 df.to_csv("tweets_24_25_variables_target.csv", sep = ";", index = False)
#
# NameError: name 'df' is not defined

# %%
dfs = [df_25_t]
df_25 = pd.DataFrame()
for dataf in dfs:
    df_aux = dataf
    df_aux["target"] = [1 for i in range(df_aux.shape[0])]
    df_25 = pd.concat([df_25, df_aux])
    
dfs = [df_25_nt]
for dataf in dfs:
    df_aux = dataf
    df_aux["target"] = [0 for i in range(df_aux.shape[0])]
    df_25 = pd.concat([df_25, df_aux])

# %%
df_24.to_csv("tweets_24_variables_target_7h.csv", sep = ";", index = False)
df_25.to_csv("tweets_25_variables_target_7h.csv", sep = ";", index = False)

# %%
df1 = pd.read_csv("C:/Users/Daniel/Documents/GitHub/SuperProyecto/Notebooks PROYECTO/Q3_tweets_25_tendencias_variables_7h.csv", sep = ";")
df2 = pd.read_csv("C:/Users/Daniel/Documents/GitHub/SuperProyecto/Notebooks PROYECTO/Q3_tweets_25_notendencias_variables_7h.csv", sep = ";")

# %%
dfs = [df1]
df_24 = pd.DataFrame()
for dataf in dfs:
    df_aux = dataf
    df_aux["target"] = [1 for i in range(df_aux.shape[0])]
    df_24 = pd.concat([df_24, df_aux])
    
dfs = [df2]
for dataf in dfs:
    df_aux = dataf
    df_aux["target"] = [0 for i in range(df_aux.shape[0])]
    df_24 = pd.concat([df_24, df_aux])
    
df_24.to_csv("Q3_tweets_25_variables_target_7h.csv", sep = ";", index = False)

# %%
df_24
# Out:
#                   trend  start_lifetime  total_tweets  total_hashtags  \
# 0               Tavares              22           416             433
# 1                Feddal              17           679             822
# 2        Michael Jordan              21           827             875
# 3   #PremiosOCRMallorca              19            62             132
# 4        Vanessa Bryant              20           200             265
# ..                  ...             ...           ...             ...
# 31                llama               8            58              58
# 32               equipo               8             5               5
# 33                nunca              12             3               5
# 34          coronavirus               9             1               1
# 35              oficial               9            17              17
#
#     total_mentions  total_reply_to  total_url  total_photo  total_retweets  \
# ...
